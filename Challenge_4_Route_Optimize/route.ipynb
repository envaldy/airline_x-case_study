# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("routes.csv")
df.head()
# Out:
#   airline airline ID  source airport  source airport id  destination apirport  \
# 0      2B        410             AER               2965                   KZN
# 1      2B        410             ASF               2966                   KZN
# 2      2B        410             ASF               2966                   MRV
# 3      2B        410             CEK               2968                   KZN
# 4      2B        410             CEK               2968                   OVB
#
#    destination airport id  codeshare   stops  equipment
# 0                    2990        NaN       0        CR2
# 1                    2990        NaN       0        CR2
# 2                    2962        NaN       0        CR2
# 3                    2990        NaN       0        CR2
# 4                    4078        NaN       0        CR2

# %%
df_cgk = df[df[" source airport"]=='CGK']
df_cgk
# Out:
#       airline airline ID  source airport  source airport id  \
# 1841       5J       1683             CGK               3275
# 9425       AF        137             CGK               3275
# 10692      AK        576             CGK               3275
# 10693      AK        576             CGK               3275
# 13200      AZ        596             CGK               3275
# ...       ...        ...             ...                ...
# 53844      TR       4936             CGK               3275
# 58023      UL       4349             CGK               3275
# 61342      VF       5297             CGK               3275
# 61409      VN       5309             CGK               3275
# 65596      XY       3754             CGK               3275
#
#        destination apirport  destination airport id  codeshare   stops  \
# 1841                    MNL                    2397        NaN       0
# 9425                    KUL                    3304          Y       0
# ...

# %%
df_cgk.columns
# Out:
# Index(['airline', 'airline ID', ' source airport', ' source airport id',
#        ' destination apirport', ' destination airport id', ' codeshare',
#        ' stops', ' equipment'],
#       dtype='object')

# %% [markdown]
# ---

# %%
df_cgk_sin = df_cgk[df_cgk[" destination apirport"]=="SIN"]
df_cgk_sin
# Out:
#       airline airline ID  source airport  source airport id  \
# 29604      GA       2520             CGK               3275
# 35151      JT       3290             CGK               3275
# 40110      MF       5484             CGK               3275
# 46830      QF       4089             CGK               3275
# 47700      QZ       2857             CGK               3275
# 47901      RI       3391             CGK               3275
# 50438      SQ       4435             CGK               3275
# 52314      TK       4951             CGK               3275
# 53844      TR       4936             CGK               3275
# 61342      VF       5297             CGK               3275
#
#        destination apirport  destination airport id  codeshare   stops  \
# 29604                   SIN                    3316        NaN       0
# 35151                   SIN                    3316        NaN       0
# 40110                   SIN                    3316        NaN       0
# ...

# %%
df_cgk_bali = df_cgk[df_cgk[" destination apirport"]=="DPS"]
df_cgk_bali
# Out:
#       airline airline ID  source airport  source airport id  \
# 29580      GA       2520             CGK               3275
# 33017      ID       2896             CGK               3275
# 35137      JT       3290             CGK               3275
# 47186      QG      19305             CGK               3275
# 47694      QZ       2857             CGK               3275
# 47899      RI       3391             CGK               3275
# 49607      SJ       4454             CGK               3275
#
#        destination apirport  destination airport id  codeshare   stops  \
# 29580                   DPS                    3940        NaN       0
# 33017                   DPS                    3940        NaN       0
# 35137                   DPS                    3940        NaN       0
# 47186                   DPS                    3940        NaN       0
# 47694                   DPS                    3940        NaN       0
# ...

# %%
df_cgk_jpn = df_cgk[df_cgk[" destination apirport"]=="HND"]
df_cgk_jpn
# Out:
#       airline airline ID  source airport  source airport id  \
# 29582      GA       2520             CGK               3275
# 42773      NH        324             CGK               3275
#
#        destination apirport  destination airport id  codeshare   stops  \
# 29582                   HND                    2359        NaN       0
# 42773                   HND                    2359        NaN       0
#
#        equipment
# 29582        788
# 42773        788

# %%
df_cgk_aus = df_cgk[df_cgk[" destination apirport"]=="SYD"]
df_cgk_aus
# Out:
#       airline airline ID  source airport  source airport id  \
# 29608      GA       2520             CGK               3275
# 36540      KL       3090             CGK               3275
# 46831      QF       4089             CGK               3275
#
#        destination apirport  destination airport id  codeshare   stops  \
# 29608                   SYD                    3361        NaN       0
# 36540                   SYD                    3361        NaN       0
# 46831                   SYD                    3361        NaN       0
#
#        equipment
# 29608        332
# 36540        330
# 46831        333

# %%
df_cgk_kenedy = df_cgk[df_cgk[" destination apirport"]=="JFK"]
df_cgk_kenedy
# Out:
# Empty DataFrame
# Columns: [airline, airline ID,  source airport,  source airport id,  destination apirport,  destination airport id,  codeshare,  stops,  equipment]
# Index: []

# %% [markdown]
# ---

# %%
df_o = pd.read_csv("case_route.csv")

# %%
df_o
# Out:
#    Unnamed: 0      Flight Revenue  Revenue per Flight  Operating Cost  \
# 0           0    Jakarta - Sydney               50000           30000
# 1           1  Jakarta- Singapore               15000           10000
# 2           2      Jakarta - Bali                5000            3500
# 3           3     Jakarta - Tokyo               40000           25000
# 4           4  Jakarta - New York               70000           55000
#
#    Net Revenue
# 0        20000
# 1         5000
# 2         1500
# 3        15000
# 4        15000

# %%
df_o.drop(columns=["Unnamed: 0","Revenue per Flight","Operating Cost","Net Revenue"],inplace=True)

# %%
df_o["times"] = [3, 10, 7, 2, 0]

# %%
df_o
# Out:
#        Flight Revenue  times
# 0    Jakarta - Sydney      3
# 1  Jakarta- Singapore     10
# 2      Jakarta - Bali      7
# 3     Jakarta - Tokyo      2
# 4  Jakarta - New York      0

# %%
plt.figure(figsize=(10,8))
df_sorted = df_o.sort_values(by='times', ascending=False)
barplot = sns.barplot(y='Flight Revenue',x='times',data=df_sorted,errorbar=None, palette='viridis')

plt.ylabel('Flight')

for p in barplot.patches:
    barplot.annotate(format(p.get_width(), '.0f'),
                     (p.get_width(), p.get_y() + p.get_height() / 2.),
                     ha = 'center', va = 'center',
                     xytext = (15, 0),
                     textcoords = 'offset points')
plt.title('Flight Frequent')
plt.xticks(rotation=0)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12')])

# %%
df_r = pd.read_csv("case_route.csv")

# %%
df_r["profit margin"] = df_r['Net Revenue']/df_r['Revenue per Flight']

# %%
df_r
# Out:
#    Unnamed: 0      Flight Revenue  Revenue per Flight  Operating Cost  \
# 0           0    Jakarta - Sydney               50000           30000
# 1           1  Jakarta- Singapore               15000           10000
# 2           2      Jakarta - Bali                5000            3500
# 3           3     Jakarta - Tokyo               40000           25000
# 4           4  Jakarta - New York               70000           55000
#
#    Net Revenue  profit margin
# 0        20000       0.400000
# 1         5000       0.333333
# 2         1500       0.300000
# 3        15000       0.375000
# 4        15000       0.214286

# %%
plt.figure(figsize=(10,8))
# df_r_sorted = df_r.sort_values(by='profit margin', ascending=False)
barplot = sns.barplot(x='Flight Revenue',y='profit margin',data=df_r,errorbar=None, palette='GnBu_r')
plt.title('Profit Margin')


for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.2f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 10), 
                     textcoords = 'offset points')
